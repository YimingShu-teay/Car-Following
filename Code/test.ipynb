# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def calc(num1,num2):
    return(num2-num1)/num1
list1=[2.93,5.95,7.21,17.5,30.2,32,38.4,43,53,73,102,106,115,130]
final_outcome=[]
for i in range(len(list1)):
    if i != len(list1)-1:
        final_outcome.append(calc(list1[i],list1[i+1]))
    else:
        final_outcome.append(calc(list1[i-1],list1[i]))

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.gaussian_process import GaussianProcessRegressor
a=np.random.random(50).reshape(50,1)
b=a*2+np.random.random(50).reshape(50,1)
plt.scatter(a,b,marker = 'o', color = 'r', label='3', s = 15)
plt.show()
gaussian=GaussianProcessRegressor()
fiting=gaussian.fit(a,b)
c=np.linspace(0.1,1,100)
d=gaussian.predict(c.reshape(100,1))
plt.scatter(a,b,marker = 'o', color = 'r', label='3', s = 15)
plt.plot(c,d)
plt.show()

# %%
import pandas as pd
time_dict = {'time_30.100000000000158': 30.100000000000158, 'time_30.20000000000016': 30.20000000000016}
def save_value_to_excel(td):
    df = pd.read_excel(r"C:\Users\sym02\Desktop\first project code\code1\LAS_50.xlsx")    
    Time_dict = td
    value_list = []
    for key,value in Time_dict.items():
        value_list.append(value)
    df.loc[len(df.index),"500"] = value_list[1]
    print(len(df.index))
    value_list

# %%
def save_to_excel_50(dir,Time_dict):
    value_list = []
    for key,value in Time_dict.items():
        value_list.append(value)
    df = pd.read_excel(dir) 
    df = df[["500","800"]]
    df.loc[len(df)] = [value_list[-1],0]
    df.to_excel(dir)
save_to_excel_50(r"C:\Users\sym02\Desktop\first project code\code1\LAS_50.xlsx",time_dict)

# %%
df_test.loc[len(df_test)] = [0,5]
df_test.loc[0,"800"] = 6
df_test
# Out:
#     500  800
# 0  30.2  6.0
# 1   0.0  5.0
# 2   0.0  5.0

# %%
50LAS_50 = pd.read_excel(r"C:\Users\sym02\Desktop\first project code\code1\LAS_50.xlsx")
LAS_50.columns[0]
# Out:
# 500

# %%
import numpy as np
df.loc[0,"500"]
# Out:
# 0

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    1529         try:
# -> 1530             return self.obj._take_with_is_copy(key, axis=axis)
#    1531         except IndexError as err:
#
# d:\Anaconda\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3627         """
# -> 3628         result = self.take(indices=indices, axis=axis)
#    3629         # Maybe set copy if we didn't actually change the index.
#
# d:\Anaconda\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3614
# -> 3615         new_data = self._mgr.take(
#    3616             indices, axis=self._get_block_manager_axis(axis), verify=True
#
# d:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify)
# ...

# %%
LAS_50
# Out:
# Empty DataFrame
# Columns: [500, 500, 800]
# Index: []
